# %%
import numpy as np
import  matplotlib.pyplot as plt
from sklearn.datasets import load_sample_image
from sklearn.datasets import load_digits
from sklearn.cluster import KMeans
from sklearn.metrics import confusion_matrix, accuracy_score
from scipy.stats import mode

# %%
digits = load_digits()
X = digits.data
y = digits.target

# %%
k_means = KMeans(n_clusters=10)
predict = k_means.fit_predict(X)

# %%
labels = np.zeros_like(predict)
for i in range(10):
    mask = (predict==i)
    labels[mask] = mode(y[mask])[0]

# %%
print("Accuracy Score: ", accuracy_score(y,labels))
print("\nConfusion Matrix: \n", confusion_matrix(y, labels))
# Out:
# Accuracy Score:  0.7941012799109627
#
# Confusion Matrix:
#  [[176   0   0   0   2   0   0   0   0   0]
#  [  0 154  24   1   0   1   2   0   0   0]
#  [  1  10 148  13   0   0   0   3   0   2]
#  [  0   7   0 154   0   2   0   7   0  13]
#  [  0   7   0   0 166   0   0   8   0   0]
#  [  0   0   0   0   2 136   1   0   0  43]
#  [  1   3   0   0   0   0 177   0   0   0]
#  [  0   2   0   0   0   0   0 177   0   0]
#  [  0 106   3   2   0   4   2   5   0  52]
#  [  0  22   0   6   0   6   0   7   0 139]]

# %%
from sklearn.datasets import load_sample_image
img=load_sample_image('china.jpg')
# Out:
# C:\Users\Kavya\Anaconda3\lib\site-packages\sklearn\datasets\base.py:762: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   images = [imread(filename) for filename in filenames]
# C:\Users\Kavya\Anaconda3\lib\site-packages\sklearn\datasets\base.py:762: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
#   images = [imread(filename) for filename in filenames]

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (427, 640, 3)

# %%
l,h,d=img.shape
img_arr=np.reshape(img,(l*h,d))
model = KMeans(n_clusters=7)
fimg = model.fit(img_arr)

# %%
labels = model.predict(img_arr)

# %%
a=np.reshape(labels,(427,640))
plt.imshow(a)
