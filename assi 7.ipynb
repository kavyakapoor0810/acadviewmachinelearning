# %%
print("EDA")
# Out:
# EDA

# %%
print("Assignment 7")
# Out:
# Assignment 7

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_csv('day.csv')

# %%
data.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
data.shape
# Out:
# (731, 16)

# %%
data.size
# Out:
# 11696

# %%
list(data.columns)
# Out:
# ['instant',
#  'dteday',
#  'season',
#  'yr',
#  'mnth',
#  'holiday',
#  'weekday',
#  'workingday',
#  'weathersit',
#  'temp',
#  'atemp',
#  'hum',
#  'windspeed',
#  'casual',
#  'registered',
#  'cnt']

# %%
data.describe(include='all')
# Out:
#            instant      dteday      season          yr        mnth  \
# count   731.000000         731  731.000000  731.000000  731.000000
# unique         NaN         731         NaN         NaN         NaN
# top            NaN  2011-02-15         NaN         NaN         NaN
# freq           NaN           1         NaN         NaN         NaN
# mean    366.000000         NaN    2.496580    0.500684    6.519836
# std     211.165812         NaN    1.110807    0.500342    3.451913
# min       1.000000         NaN    1.000000    0.000000    1.000000
# 25%     183.500000         NaN    2.000000    0.000000    4.000000
# 50%     366.000000         NaN    3.000000    1.000000    7.000000
# 75%     548.500000         NaN    3.000000    1.000000   10.000000
# max     731.000000         NaN    4.000000    1.000000   12.000000
#
#            holiday     weekday  workingday  weathersit        temp  \
# count   731.000000  731.000000  731.000000  731.000000  731.000000
# ...

# %%
data.isnull().sum()
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
plt.hist(x='instant' ,data=data,bins=80)
plt.grid()
plt.title('Count plot of instant in day')
# Out:
# Text(0.5,1,'Count plot of instant in day')

# %%
plt.hist(x='season' ,data=data,bins=50)
plt.grid()
plt.title('Count plot of season in day')
# Out:
# Text(0.5,1,'Count plot of season in day')

# %%
plt.hist(x='temp' ,data=data,bins=50)
plt.grid()
plt.title('Count plot of temp in day')
# Out:
# Text(0.5,1,'Count plot of temp in day')

# %%
plt.hist(x='windspead' ,data=data,bins=50)
plt.grid()
plt.title('Count plot of windspead in day')
# Out:
# Text(0.5,1,'Count plot of windspead in day')

# %%
sns.distplot(data['casual'])
plt.title("casual ")
plt.show()
# Out:
# C:\Users\Kavya\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(data['registered' ])
plt.title("registered")
plt.show()
# Out:
# C:\Users\Kavya\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(data['weathersit' ])
plt.title("weathersit")
plt.show()
# Out:
# C:\Users\Kavya\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.hist(data['workingday'],bins=10 )
plt.title('working day')
plt.xlabel('work')
plt.ylabel('day')
# Out:
# Text(0,0.5,'day')

# %%
plt.figure(figsize=(12,8))
sns.heatmap(data.corr(),annot=True)

# %%
plt.figure(figsize=(10,6))
sns.regplot(x='weekday', y='holiday', data=data, x_jitter=0.3, scatter_kws={'alpha':0.2})
sns.despine()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'windspead'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-1de991cf967a> in <module>()
#       1 plt.figure(figsize=(10,6))
# ...
